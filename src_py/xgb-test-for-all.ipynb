# %%
import xgboost as xgb
import pandas as pd
import numpy as np
import janitor
from xgboost.sklearn import XGBClassifier
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV, GridSearchCV
# import pickle
from joblib import dump, load
from matplotlib import pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline

SEED = 24601

# %%
# %pwd

# %%
data = pd.read_csv('../OMAD_adverse_outcome_mod/data/ALL-STU-transformed-data-to-py.csv',
                   na_values=['NA', 'NaN', 'Inf', '-Inf'])

if 'Unnamed: 0' in data.columns:
    data.drop(columns='Unnamed: 0', inplace=True)

data.dropna(subset=['Y'], inplace=True)
data = data[data['class'] <= 4]
data = janitor.clean_names(data)

id_vars = ['system_key', 'yrq', 'tran_major_abbr']
target = 'y'
x_vars = [x for x in data.columns if x not in [target]]
x_vars = [x for x in x_vars if x not in id_vars]

# %%
data_sub = data.sample(n = 10000, random_state=24601)
train, test, train_y, test_y = train_test_split(data_sub[x_vars],
                                                    data_sub[target],
                                                    test_size=0.25,
                                                    random_state=SEED)
                                                # , stratify=data[target])

# %%
if test.shape[1] != train.shape[1]:
    i1 = train.columns
    i2 = test.columns
    [x for x in i2 if x not in i1]
else: 
    print("√ train/test have same number of columns √")
# Out:
# √ train/test have same number of columns √

# %%
dtrain = xgb.DMatrix(train, label = train_y, missing = np.NaN)
dtest = xgb.DMatrix(test, label = test_y, missing = np.NaN)

# %%
param = {'max_depth': 4, 
         'eta': 1, 
         'objective': 'reg:squarederror'}
evallist = [(dtest, 'eval'), (dtrain, 'train')]
nrounds = 3

# %%
bst = xgb.train(param, dtrain, nrounds, evallist)
# Out:
# [0]	eval-rmse:0.36857	train-rmse:0.36754
# [1]	eval-rmse:0.36432	train-rmse:0.35910
# [2]	eval-rmse:0.36510	train-rmse:0.35404
# /Users/zane/opt/anaconda3/lib/python3.9/site-packages/xgboost/core.py:617: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)

# %%
bst.predict(dtest)[:20]
# Out:
# array([ 2.9648980e-04,  8.3729553e-01, -4.2395657e-01, -6.2477533e-03,
#         3.8774461e-01,  1.3595320e-01,  7.9382801e-01,  4.1852258e-02,
#         9.7223133e-01, -1.2916803e-02,  3.7928790e-01, -1.4015157e-02,
#         5.6459981e-01, -6.7548454e-04,  5.0611454e-01,  5.6264472e-01,
#         2.5726311e-02, -6.2477533e-03,  6.2943703e-01, -6.2477533e-03],
#       dtype=float32)

# %%
# setup search grid
param_grid = {
    'min_child_weight': [1, 3, 5, 10],
    'gamma': [.5, 1, 1.5, 2, 5],
    'subsample': [.4, .6, .8],
    'colsample_bytree': [.4, .6, .8],
    'max_depth': [3, 5, 7, 9]
}
print("There are", np.prod([len(x) for x in param_grid.values()]), "elements to search over")
# Out:
# There are 720 elements to search over

# %%
xgb_mod = XGBClassifier(learning_rate = .05, 
                        n_estimators = 600, 
                        objective = 'reg:squarederror', 
                        silent = False, 
                        nthread = -1)

# %%
# init small values for testing, even small numbers will take a long time here
nfolds = 5
param_comb = 20

kf = KFold(n_splits = nfolds, shuffle = True, random_state = 1001)
random_search = RandomizedSearchCV(xgb_mod, 
                                   param_distributions = param_grid, 
                                   n_iter = param_comb,
                                   scoring = 'neg_mean_absolute_error',
                                   n_jobs = -1,
                                   cv = kf.split(train, train_y),
                                   verbose = 3,
                                   random_state = 1001)

random_search.fit(train, train_y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [08:54:11] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/learner.cc:767:
# Parameters: { "silent" } are not used.
# RandomizedSearchCV(cv=<generator object _BaseKFold.split at 0x7fe4c14a4890>,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, gpu_id=None,
#                                            grow_policy=None,
#                                            importance_type...
#                                            monotone_constraints=None,
#                                            n_estimators=600, n_jobs=None,
#                                            nthread=-1, num_parallel_tree=None,
#                                            objective='reg:squarederror', ...),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.4, 0.6, 0.8],
#                                         'gamma': [0.5, 1, 1.5, 2, 5],
#                                         'max_depth': [3, 5, 7, 9],
#                                         'min_child_weight': [1, 3, 5, 10],
#                                         'subsample': [0.4, 0.6, 0.8]},
#                    random_state=1001, scoring='neg_mean_absolute_error',
#                    verbose=3)

# %%
# display results
print("CV results:\n", random_search.cv_results_)
print("Best estimator:\n", random_search.best_estimator_)
print("Best params:\n", random_search.best_params_)
# Out:
# CV results:
#  {'mean_fit_time': array([61.66331768, 34.78045807, 15.59104905, 49.93664069, 35.20537581,
#        47.74228444, 16.06804056, 33.75009227, 17.98184938, 26.22321701,
#        20.24742556, 39.19230595, 28.76943593, 39.99711628, 28.15451765,
#        53.55149322, 33.53735785, 35.62714314, 28.08703914, 29.49678283]), 'std_fit_time': array([0.20547414, 0.08247883, 1.22310223, 0.08861151, 0.3330653 ,
#        0.19351613, 0.02925602, 0.09358727, 0.1094194 , 0.10857977,
#        0.13291046, 0.72243209, 0.02989838, 0.14783251, 0.05933976,
#        0.11115367, 0.11035403, 0.57681377, 0.15328704, 4.66837372]), 'mean_score_time': array([0.05391464, 0.03159423, 0.03293233, 0.06022739, 0.02198572,
#        0.03131499, 0.02173223, 0.05435181, 0.02507272, 0.05223093,
#        0.02503576, 0.02810607, 0.05334806, 0.02416148, 0.03227673,
#        0.04088244, 0.02895508, 0.05229216, 0.02169909, 0.01635547]), 'std_score_time': array([0.01620054, 0.00129173, 0.00706384, 0.00554026, 0.00260533,
#        0.00112579, 0.00057725, 0.00208433, 0.00087601, 0.00239508,
#        0.00119674, 0.00106556, 0.00397989, 0.00145473, 0.00296491,
#        0.00239843, 0.00141341, 0.00515833, 0.00128526, 0.00199436]), 'param_subsample': masked_array(data=[0.8, 0.8, 0.8, 0.6, 0.6, 0.6, 0.6, 0.6, 0.4, 0.8, 0.6,
#                    0.8, 0.8, 0.6, 0.6, 0.8, 0.4, 0.8, 0.6, 0.6],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_min_child_weight': masked_array(data=[10, 10, 5, 5, 5, 5, 1, 5, 1, 5, 1, 10, 3, 3, 5, 1, 3,
#                    10, 10, 10],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[9, 7, 3, 7, 5, 9, 3, 9, 3, 7, 3, 7, 5, 7, 7, 9, 7, 9,
#                    7, 7],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[1, 1.5, 1, 0.5, 5, 1.5, 2, 0.5, 1.5, 0.5, 1.5, 2, 0.5,
#                    5, 2, 1, 2, 0.5, 5, 2],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_colsample_bytree': masked_array(data=[0.8, 0.6, 0.6, 0.8, 0.8, 0.6, 0.6, 0.4, 0.8, 0.4, 0.8,
#                    0.6, 0.6, 0.6, 0.4, 0.6, 0.6, 0.4, 0.4, 0.6],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'subsample': 0.8, 'min_child_weight': 10, 'max_depth': 9, 'gamma': 1, 'colsample_bytree': 0.8}, {'subsample': 0.8, 'min_child_weight': 10, 'max_depth': 7, 'gamma': 1.5, 'colsample_bytree': 0.6}, {'subsample': 0.8, 'min_child_weight': 5, 'max_depth': 3, 'gamma': 1, 'colsample_bytree': 0.6}, {'subsample': 0.6, 'min_child_weight': 5, 'max_depth': 7, 'gamma': 0.5, 'colsample_bytree': 0.8}, {'subsample': 0.6, 'min_child_weight': 5, 'max_depth': 5, 'gamma': 5, 'colsample_bytree': 0.8}, {'subsample': 0.6, 'min_child_weight': 5, 'max_depth': 9, 'gamma': 1.5, 'colsample_bytree': 0.6}, {'subsample': 0.6, 'min_child_weight': 1, 'max_depth': 3, 'gamma': 2, 'colsample_bytree': 0.6}, {'subsample': 0.6, 'min_child_weight': 5, 'max_depth': 9, 'gamma': 0.5, 'colsample_bytree': 0.4}, {'subsample': 0.4, 'min_child_weight': 1, 'max_depth': 3, 'gamma': 1.5, 'colsample_bytree': 0.8}, {'subsample': 0.8, 'min_child_weight': 5, 'max_depth': 7, 'gamma': 0.5, 'colsample_bytree': 0.4}, {'subsample': 0.6, 'min_child_weight': 1, 'max_depth': 3, 'gamma': 1.5, 'colsample_bytree': 0.8}, {'subsample': 0.8, 'min_child_weight': 10, 'max_depth': 7, 'gamma': 2, 'colsample_bytree': 0.6}, {'subsample': 0.8, 'min_child_weight': 3, 'max_depth': 5, 'gamma': 0.5, 'colsample_bytree': 0.6}, {'subsample': 0.6, 'min_child_weight': 3, 'max_depth': 7, 'gamma': 5, 'colsample_bytree': 0.6}, {'subsample': 0.6, 'min_child_weight': 5, 'max_depth': 7, 'gamma': 2, 'colsample_bytree': 0.4}, {'subsample': 0.8, 'min_child_weight': 1, 'max_depth': 9, 'gamma': 1, 'colsample_bytree': 0.6}, {'subsample': 0.4, 'min_child_weight': 3, 'max_depth': 7, 'gamma': 2, 'colsample_bytree': 0.6}, {'subsample': 0.8, 'min_child_weight': 10, 'max_depth': 9, 'gamma': 0.5, 'colsample_bytree': 0.4}, {'subsample': 0.6, 'min_child_weight': 10, 'max_depth': 7, 'gamma': 5, 'colsample_bytree': 0.4}, {'subsample': 0.6, 'min_child_weight': 10, 'max_depth': 7, 'gamma': 2, 'colsample_bytree': 0.6}], 'split0_test_score': array([-0.18733333, -0.188     , -0.186     , -0.18266667, -0.18933333,
#        -0.18333333, -0.18866667, -0.184     , -0.18733333, -0.18466667,
#        -0.18933333, -0.18733333, -0.184     , -0.19333333, -0.18466667,
#        -0.186     , -0.186     , -0.18666667, -0.18866667, -0.18066667]), 'split1_test_score': array([-0.20733333, -0.21      , -0.21466667, -0.20733333, -0.22066667,
#        -0.204     , -0.21733333, -0.21266667, -0.21533333, -0.21066667,
#        -0.212     , -0.214     , -0.21      , -0.22466667, -0.216     ,
#        -0.21066667, -0.21133333, -0.20733333, -0.22133333, -0.214     ]), 'split2_test_score': array([-0.18733333, -0.19      , -0.18666667, -0.18933333, -0.206     ,
#        -0.19133333, -0.19466667, -0.188     , -0.19333333, -0.18866667,
#        -0.188     , -0.19      , -0.18933333, -0.20333333, -0.194     ,
#        -0.17666667, -0.19333333, -0.198     , -0.19666667, -0.19      ]), 'split3_test_score': array([-0.20333333, -0.18933333, -0.19333333, -0.188     , -0.19333333,
#        -0.19733333, -0.18333333, -0.2       , -0.19133333, -0.20533333,
#        -0.19333333, -0.18333333, -0.18866667, -0.19333333, -0.192     ,
#        -0.18866667, -0.19      , -0.20466667, -0.19933333, -0.18533333]), 'split4_test_score': array([-0.18066667, -0.18066667, -0.18066667, -0.19266667, -0.19066667,
#        -0.192     , -0.18666667, -0.19133333, -0.18533333, -0.18466667,
#        -0.18533333, -0.17933333, -0.17866667, -0.19133333, -0.188     ,
#        -0.188     , -0.184     , -0.18      , -0.19133333, -0.18133333]), 'mean_test_score': array([-0.1932    , -0.1916    , -0.19226667, -0.192     , -0.2       ,
#        -0.1936    , -0.19413333, -0.1952    , -0.19453333, -0.1948    ,
#        -0.1936    , -0.1908    , -0.19013333, -0.2012    , -0.19493333,
#        -0.19      , -0.19293333, -0.19533333, -0.19946667, -0.19026667]), 'std_test_score': array([0.01027965, 0.00978525, 0.01190033, 0.00831598, 0.01190331,
#        0.00685857, 0.0121721 , 0.01020152, 0.01077775, 0.01100626,
#        0.00955545, 0.01215017, 0.01064498, 0.01246078, 0.01101595,
#        0.01119524, 0.00974885, 0.01047325, 0.01156547, 0.01232594]), 'rank_test_score': array([ 9,  5,  7,  6, 19, 10, 12, 16, 13, 14, 10,  4,  2, 20, 15,  1,  8,
#        17, 18,  3], dtype=int32)}
# Best estimator:
#  XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.6,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=1, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.05, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=9, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=600, n_jobs=-1,
#               nthread=-1, num_parallel_tree=1, objective='reg:squarederror', ...)
# Best params:
#  {'subsample': 0.8, 'min_child_weight': 1, 'max_depth': 9, 'gamma': 1, 'colsample_bytree': 0.6}

# %%
# pickle the result to avoid re-training
dump(random_search.best_estimator_, './OMAD_adverse_outcome_mod/models/xgb-test-best-estimator_01042023.joblib')
# Out:
# ['./OMAD_adverse_outcome_mod/models/xgb-test-best-estimator_01042023.joblib']

# %%
results = pd.DataFrame(random_search.cv_results_)
results.to_csv('./OMAD_adverse_outcome_mod/models/xgb-random-grid-search-test-results.csv', index = False)

# %%
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       61.663318      0.205474         0.053915        0.016201
# 1       34.780458      0.082479         0.031594        0.001292
# 2       15.591049      1.223102         0.032932        0.007064
# 3       49.936641      0.088612         0.060227        0.005540
# 4       35.205376      0.333065         0.021986        0.002605
# 5       47.742284      0.193516         0.031315        0.001126
# 6       16.068041      0.029256         0.021732        0.000577
# 7       33.750092      0.093587         0.054352        0.002084
# 8       17.981849      0.109419         0.025073        0.000876
# 9       26.223217      0.108580         0.052231        0.002395
# 10      20.247426      0.132910         0.025036        0.001197
# 11      39.192306      0.722432         0.028106        0.001066
# 12      28.769436      0.029898         0.053348        0.003980
# 13      39.997116      0.147833         0.024161        0.001455
# 14      28.154518      0.059340         0.032277        0.002965
# 15      53.551493      0.111154         0.040882        0.002398
# 16      33.537358      0.110354         0.028955        0.001413
# 17      35.627143      0.576814         0.052292        0.005158
# 18      28.087039      0.153287         0.021699        0.001285
# 19      29.496783      4.668374         0.016355        0.001994
#
#    param_subsample param_min_child_weight param_max_depth param_gamma  \
# 0              0.8                     10               9           1
# 1              0.8                     10               7         1.5
# 2              0.8                      5               3           1
# 3              0.6                      5               7         0.5
# 4              0.6                      5               5           5
# 5              0.6                      5               9         1.5
# 6              0.6                      1               3           2
# 7              0.6                      5               9         0.5
# 8              0.4                      1               3         1.5
# 9              0.8                      5               7         0.5
# 10             0.6                      1               3         1.5
# 11             0.8                     10               7           2
# 12             0.8                      3               5         0.5
# 13             0.6                      3               7           5
# 14             0.6                      5               7           2
# 15             0.8                      1               9           1
# 16             0.4                      3               7           2
# 17             0.8                     10               9         0.5
# 18             0.6                     10               7           5
# 19             0.6                     10               7           2
#
#    param_colsample_bytree                                             params  \
# 0                     0.8  {'subsample': 0.8, 'min_child_weight': 10, 'ma...
# 1                     0.6  {'subsample': 0.8, 'min_child_weight': 10, 'ma...
# 2                     0.6  {'subsample': 0.8, 'min_child_weight': 5, 'max...
# 3                     0.8  {'subsample': 0.6, 'min_child_weight': 5, 'max...
# 4                     0.8  {'subsample': 0.6, 'min_child_weight': 5, 'max...
# 5                     0.6  {'subsample': 0.6, 'min_child_weight': 5, 'max...
# 6                     0.6  {'subsample': 0.6, 'min_child_weight': 1, 'max...
# 7                     0.4  {'subsample': 0.6, 'min_child_weight': 5, 'max...
# 8                     0.8  {'subsample': 0.4, 'min_child_weight': 1, 'max...
# 9                     0.4  {'subsample': 0.8, 'min_child_weight': 5, 'max...
# 10                    0.8  {'subsample': 0.6, 'min_child_weight': 1, 'max...
# 11                    0.6  {'subsample': 0.8, 'min_child_weight': 10, 'ma...
# 12                    0.6  {'subsample': 0.8, 'min_child_weight': 3, 'max...
# 13                    0.6  {'subsample': 0.6, 'min_child_weight': 3, 'max...
# 14                    0.4  {'subsample': 0.6, 'min_child_weight': 5, 'max...
# 15                    0.6  {'subsample': 0.8, 'min_child_weight': 1, 'max...
# 16                    0.6  {'subsample': 0.4, 'min_child_weight': 3, 'max...
# 17                    0.4  {'subsample': 0.8, 'min_child_weight': 10, 'ma...
# 18                    0.4  {'subsample': 0.6, 'min_child_weight': 10, 'ma...
# 19                    0.6  {'subsample': 0.6, 'min_child_weight': 10, 'ma...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0           -0.187333          -0.207333          -0.187333
# 1           -0.188000          -0.210000          -0.190000
# 2           -0.186000          -0.214667          -0.186667
# 3           -0.182667          -0.207333          -0.189333
# 4           -0.189333          -0.220667          -0.206000
# 5           -0.183333          -0.204000          -0.191333
# 6           -0.188667          -0.217333          -0.194667
# 7           -0.184000          -0.212667          -0.188000
# 8           -0.187333          -0.215333          -0.193333
# 9           -0.184667          -0.210667          -0.188667
# 10          -0.189333          -0.212000          -0.188000
# 11          -0.187333          -0.214000          -0.190000
# 12          -0.184000          -0.210000          -0.189333
# 13          -0.193333          -0.224667          -0.203333
# 14          -0.184667          -0.216000          -0.194000
# 15          -0.186000          -0.210667          -0.176667
# 16          -0.186000          -0.211333          -0.193333
# 17          -0.186667          -0.207333          -0.198000
# 18          -0.188667          -0.221333          -0.196667
# 19          -0.180667          -0.214000          -0.190000
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0           -0.203333          -0.180667        -0.193200        0.010280
# 1           -0.189333          -0.180667        -0.191600        0.009785
# 2           -0.193333          -0.180667        -0.192267        0.011900
# 3           -0.188000          -0.192667        -0.192000        0.008316
# 4           -0.193333          -0.190667        -0.200000        0.011903
# 5           -0.197333          -0.192000        -0.193600        0.006859
# 6           -0.183333          -0.186667        -0.194133        0.012172
# 7           -0.200000          -0.191333        -0.195200        0.010202
# 8           -0.191333          -0.185333        -0.194533        0.010778
# 9           -0.205333          -0.184667        -0.194800        0.011006
# 10          -0.193333          -0.185333        -0.193600        0.009555
# 11          -0.183333          -0.179333        -0.190800        0.012150
# 12          -0.188667          -0.178667        -0.190133        0.010645
# 13          -0.193333          -0.191333        -0.201200        0.012461
# 14          -0.192000          -0.188000        -0.194933        0.011016
# 15          -0.188667          -0.188000        -0.190000        0.011195
# 16          -0.190000          -0.184000        -0.192933        0.009749
# 17          -0.204667          -0.180000        -0.195333        0.010473
# 18          -0.199333          -0.191333        -0.199467        0.011565
# 19          -0.185333          -0.181333        -0.190267        0.012326
#
#     rank_test_score
# 0                 9
# 1                 5
# 2                 7
# 3                 6
# 4                19
# 5                10
# 6                12
# 7                16
# 8                13
# 9                14
# 10               10
# 11                4
# 12                2
# 13               20
# 14               15
# 15                1
# 16                8
# 17               17
# 18               18
# 19                3

# %%
print(bst.predict(dtest)[:10])
print("rs.pred()[:10] ", random_search.predict(test[:10]))
print("truth:", test_y[:10])
# Out:
# [ 2.9648980e-04  8.3729553e-01 -4.2395657e-01 -6.2477533e-03
#   3.8774461e-01  1.3595320e-01  7.9382801e-01  4.1852258e-02
#   9.7223133e-01 -1.2916803e-02]
# rs.pred()[:10]  [0 1 0 0 0 0 0 0 1 0]
# truth: 955088     0.0
# 406177     1.0
# 920468     0.0
# 539165     0.0
# 1575331    0.0
# 647361     0.0
# 1111704    0.0
# 918802     0.0
# 358173     1.0
# 607595     0.0
# Name: y, dtype: float64

# %% [markdown]
# #### Brute force solution

# %%
# grid = GridSearchCV(estimator=xgb, 
# param_grid=params, scoring='roc_auc', n_jobs=4, cv=skf.split(X,Y), verbose=3 )
# grid.fit(X, Y)
# print('\n All results:')
# print(grid.cv_results_)
# print('\n Best estimator:')
# print(grid.best_estimator_)
# print('\n Best score:')
# print(grid.best_score_ * 2 - 1)
# print('\n Best parameters:')
# print(grid.best_params_)
# results = pd.DataFrame(grid.cv_results_)
# results.to_csv('xgb-grid-search-results-01.csv', index=False)

# y_test = grid.best_estimator_.predict_proba(test)
# results_df = pd.DataFrame(data={'id':test_df['id'], 'target':y_test[:,1]})
# results_df.to_csv('submission-grid-search-xgb-porto-01.csv', index=False)
